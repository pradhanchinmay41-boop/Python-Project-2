# %% [markdown]
# # Introduction to opencv and image processing

# %%
pip install opencv-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np          # install the all library
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import cv2

# %%
img = cv2.imread(r'C:\Users\Satyabrata Sahoo\Desktop\pic\New folder\Quotefancy-8152461-3840x2160.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (2160, 3840, 3)

# %%
plt.imshow(img) # syntax for show img

# %%
img
# Out:
# array([[[171, 195, 223],
#         [168, 192, 220],
#         [169, 193, 221],
#         ...,
#         [156, 173, 192],
#         [161, 178, 197],
#         [166, 183, 202]],
#
#        [[175, 199, 227],
#         [165, 189, 217],
#         [160, 184, 212],
#         ...,
#         [159, 176, 195],
#         [160, 177, 196],
#         [163, 180, 199]],
#
#        [[172, 196, 224],
#         [167, 191, 219],
#         [163, 187, 215],
#         ...,
#         [162, 179, 198],
#         [160, 177, 196],
#         [159, 176, 195]],
#
#        ...,
#
#        [[ 14,  13,   9],
#         [ 15,  14,  10],
#         [ 15,  14,  10],
#         ...,
#         [ 11,  12,  10],
#         [ 10,  11,   9],
#         [  7,   8,   6]],
#
#        [[ 12,  11,   7],
#         [ 12,  11,   7],
#         [ 12,  11,   7],
#         ...,
#         [ 11,  12,  10],
#         [  9,  10,   8],
#         [  7,   8,   6]],
#
#        [[  8,   7,   3],
#         [  9,   8,   4],
#         [  8,   7,   3],
# ...

# %%
fix_img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB) # to fix the colour & covert BGR TO RGB

# %%
img
# Out:
# array([[[171, 195, 223],
#         [168, 192, 220],
#         [169, 193, 221],
#         ...,
#         [156, 173, 192],
#         [161, 178, 197],
#         [166, 183, 202]],
#
#        [[175, 199, 227],
#         [165, 189, 217],
#         [160, 184, 212],
#         ...,
#         [159, 176, 195],
#         [160, 177, 196],
#         [163, 180, 199]],
#
#        [[172, 196, 224],
#         [167, 191, 219],
#         [163, 187, 215],
#         ...,
#         [162, 179, 198],
#         [160, 177, 196],
#         [159, 176, 195]],
#
#        ...,
#
#        [[ 14,  13,   9],
#         [ 15,  14,  10],
#         [ 15,  14,  10],
#         ...,
#         [ 11,  12,  10],
#         [ 10,  11,   9],
#         [  7,   8,   6]],
#
#        [[ 12,  11,   7],
#         [ 12,  11,   7],
#         [ 12,  11,   7],
#         ...,
#         [ 11,  12,  10],
#         [  9,  10,   8],
#         [  7,   8,   6]],
#
#        [[  8,   7,   3],
#         [  9,   8,   4],
#         [  8,   7,   3],
# ...

# %%
fix_img.shape
# Out:
# (2160, 3840, 3)

# %%
plt.imshow(fix_img)

# %%
img_gray = cv2.imread(r'C:\Users\Satyabrata Sahoo\Desktop\pic\New folder\Quotefancy-8152461-3840x2160.jpg', cv2.IMREAD_GRAYSCALE)

# %%
img_gray.shape
# Out:
# (2160, 3840)

# %%
img_gray #to show array of the img
# Out:
# array([[201, 198, 199, ..., 177, 182, 187],
#        [205, 195, 190, ..., 180, 181, 184],
#        [202, 197, 193, ..., 183, 181, 180],
#        ...,
#        [ 12,  13,  13, ...,  11,  10,   7],
#        [ 10,  10,  10, ...,  11,   9,   7],
#        [  6,   7,   6, ...,   9,   8,   6]], dtype=uint8)

# %%
img.min()
# Out:
# np.uint8(0)

# %%
img.max()
# Out:
# np.uint8(255)

# %%
plt.imshow(img_gray)

# %%
plt.imshow(img_gray, cmap='gray') # change color to B/W

# %%
plt.imshow(img_gray, cmap='magma')

# %%
plt.imshow(img_gray, cmap='green') # green not accepted
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 plt.imshow(img_gray, cmap='green') # green not accepted
#
# File C:\ProgramData\anaconda3\Lib\site-packages\matplotlib\pyplot.py:3592, in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, colorizer, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, data, **kwargs)
#    3570 @_copy_docstring_and_deprecators(Axes.imshow)
#    3571 def imshow(
#    3572     X: ArrayLike | PIL.Image.Image,
#    (...)   3590     **kwargs,
#    3591 ) -> AxesImage:
# -> 3592     __ret = gca().imshow(
#    3593         X,
#    3594         cmap=cmap,
#    3595         norm=norm,
#    3596         aspect=aspect,
#    3597         interpolation=interpolation,
#    3598         alpha=alpha,
#    3599         vmin=vmin,
#    3600         vmax=vmax,
#    3601         colorizer=colorizer,
# ...

# %%
plt.imshow(img_gray, cmap='Wistia_r')

# %%
plt.imshow(img)

# %%
plt.imshow(fix_img)

# %%
fix_img.shape
# Out:
# (2160, 3840, 3)

# %%
fix_img_1 = cv2.resize(fix_img,(500,367))  # to resize the image

# %%
fix_img_1.shape
# Out:
# (367, 500, 3)

# %%
w_ratio = 0.5
h_ratio = 0.5

# %%
fix_img_2 =  cv2.resize(fix_img,(0,0), fix_img, w_ratio, h_ratio) #reduce img to 50% of original pic

# %%
fix_img_2
# Out:
# array([[[222, 194, 170],
#         [219, 191, 167],
#         [224, 196, 172],
#         ...,
#         [198, 179, 162],
#         [194, 175, 158],
#         [199, 180, 163]],
#
#        [[221, 193, 169],
#         [219, 191, 167],
#         [222, 194, 170],
#         ...,
#         [201, 182, 165],
#         [200, 181, 164],
#         [196, 177, 160]],
#
#        [[224, 196, 172],
#         [221, 193, 169],
#         [223, 195, 171],
#         ...,
#         [198, 179, 162],
#         [199, 180, 163],
#         [199, 180, 163]],
#
#        ...,
#
#        [[  5,   9,  10],
#         [  9,  13,  14],
#         [  7,  11,  12],
#         ...,
#         [  3,   5,   4],
#         [  5,   7,   6],
#         [  8,  10,   9]],
#
#        [[  9,  13,  14],
#         [ 10,  14,  15],
#         [  7,  11,  12],
#         ...,
#         [  7,   9,   8],
#         [  8,  10,   9],
#         [  8,  10,   9]],
#
#        [[  5,   9,  10],
#         [  5,   9,  10],
#         [  5,   9,  10],
# ...

# %%
plt.imshow(fix_img_2)

# %%
img3 = cv2.flip(fix_img_2, 0) # flip img
plt.imshow(img3)

# %%
img3 = cv2.flip(fix_img_2, 1) # flip img
plt.imshow(img3)

# %%
img3 = cv2.flip(fix_img_2, 1) # flip img
plt.imshow(img3)

# %%
cv2.imwrite('new genai image.jpg',img3) # to save image
# Out:
# True

# %%
pwd

# %% [markdown]
# # Without using matplotlib we work image with opencv

# %%
import cv2
myimg = cv2.imread(r"C:\Users\Satyabrata Sahoo\Desktop\pic\New folder\ilu.jpg")

# %%
wrong_img = cv2.imread(r'C:\Users\Satyabrata Sahoo\Desktop\pic\New folder\my image.jpg')

# %%
type(wrong_img)

# %%
type(myimg)

# %%
import cv2
myimg = cv2.imread(r"C:\Users\Satyabrata Sahoo\Desktop\pic\New folder\ilu.jpg")

cv2.imshow('ilu', myimg)

cv2.waitKey()

# %%
import cv2
myimg = cv2.imread(r"C:\Users\Satyabrata Sahoo\Desktop\pic\New folder\ilu.jpg")

while True:
    cv2.imshow('ilu', myimg)

    if cv2.waitKey(1) & 0xFF == 27 :
        break
        cv2.destroyAllwindows()

# %% [markdown]
# # **Read the video using opencv**

# %%
import cv2

cap = cv2.VideoCapture(0)  #

width = cap.get(cv2.CAP_PROP_FRAME_WIDTH)  # width frame
height = cap.get(cv2.CAP_PROP_FRAME_HEIGHT) # height  of the frame

while True:
    ret,frame = cap.read()   #read the frame
    gray = cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY)

    cv2.imshow('frame', gray)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
        cap.release()
        cv2.destroyAllwindows()

# %%
import cv2

cap = cv2.VideoCapture(0)  #

width = cap.get(cv2.CAP_PROP_FRAME_WIDTH)  # width frame
height = cap.get(cv2.CAP_PROP_FRAME_HEIGHT) # height  of the frame

while True:
    ret,frame = cap.read()   #read the frame
    gray = cv2.cvtColor(frame,cv2.COLOR_BGR2RGB)  # color change to rgb

    cv2.imshow('frame', gray)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
        cap.release()
        cv2.destroyAllwindows()
